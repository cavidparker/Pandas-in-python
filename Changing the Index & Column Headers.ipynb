# %%
import pandas as pd
import matplotlib.pyplot as plt
##from matplotlib import style
## style.use("Fivethirtyeight")

# %%
df = pd.DataFrame({"Day":[1,26,47,88], "Visitors":[200,100,300,230], "Bounce_Rate":[20,45,60,10]})

# %%
print (df)
# Out:
#    Bounce_Rate  Day  Visitors
# 0           20    1       200
# 1           45   26       100
# 2           60   47       300
# 3           10   88       230

# %%
df.plot()
plt.show()

# %% [markdown]
# ### Set the Index as a Day

# %%
df.set_index("Day", inplace = True)

# %%
print(df)
# Out:
#      Bounce_Rate  Visitors
# Day
# 1             20       200
# 26            45       100
# 47            60       300
# 88            10       230

# %%
df.plot()
plt.show()

# %% [markdown]
# ### Change The Column Name

# %%
df = df.rename(columns = {"Visitors":"Users"})

# %%
print(df)
# Out:
#      Bounce_Rate  Users
# Day
# 1             20    200
# 26            45    100
# 47            60    300
# 88            10    230

# %%
df.plot()
plt.show()
