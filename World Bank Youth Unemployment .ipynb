# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('fivethirtyeight')

# %%
dataset = pd.read_csv('API_ILO_country_YU.csv',index_col = 0) # index column is zero

# %%
dataset.head(10)
# Out:
#                      Country Code       2010       2011       2012       2013  \
# Country Name
# Afghanistan                   AFG  20.600000  20.900000  19.700001  21.100000
# Angola                        AGO  10.800000  10.700000  10.700000  10.600000
# Albania                       ALB  25.799999  27.000000  28.299999  28.700001
# Arab World                    ARB  25.022214  28.117516  29.113212  29.335306
# United Arab Emirates          ARE   9.800000   9.800000   9.800000   9.900000
# Argentina                     ARG  19.500000  18.799999  18.400000  19.700001
# Armenia                       ARM  38.299999  38.700001  35.000000  32.500000
# Australia                     AUS  11.400000  11.400000  11.700000  12.200000
# Austria                       AUT   8.800000   8.200000   8.700000   9.100000
# Azerbaijan                    AZE  14.600000  14.500000  14.300000  13.400000
#
#                            2014
# Country Name
# Afghanistan           20.799999
# ...

# %% [markdown]
# ### Define the index value as country code

# %%
df = dataset.set_index(["Country Code"])

# %%
df.head(10)
# Out:
#                    2010       2011       2012       2013       2014
# Country Code
# AFG           20.600000  20.900000  19.700001  21.100000  20.799999
# AGO           10.800000  10.700000  10.700000  10.600000  10.500000
# ALB           25.799999  27.000000  28.299999  28.700001  29.200001
# ARB           25.022214  28.117516  29.113212  29.335306  29.704569
# ARE            9.800000   9.800000   9.800000   9.900000  10.000000
# ARG           19.500000  18.799999  18.400000  19.700001  21.299999
# ARM           38.299999  38.700001  35.000000  32.500000  35.099998
# AUS           11.400000  11.400000  11.700000  12.200000  13.100000
# AUT            8.800000   8.200000   8.700000   9.100000   9.200000
# AZE           14.600000  14.500000  14.300000  13.400000  13.600000

# %% [markdown]
# ### Use Only two year (2010 & 2011)

# %%
sd = df.reindex(columns = ['2010', '2011'])

# %%
sd.head(10)
# Out:
#                    2010       2011
# Country Code
# AFG           20.600000  20.900000
# AGO           10.800000  10.700000
# ALB           25.799999  27.000000
# ARB           25.022214  28.117516
# ARE            9.800000   9.800000
# ARG           19.500000  18.799999
# ARM           38.299999  38.700001
# AUS           11.400000  11.400000
# AUT            8.800000   8.200000
# AZE           14.600000  14.500000

# %%
db = sd.diff(axis = 1)

# %%
db.head(10)
# Out:
#               2010      2011
# Country Code
# AFG            NaN  0.299999
# AGO            NaN -0.100000
# ALB            NaN  1.200001
# ARB            NaN  3.095302
# ARE            NaN  0.000000
# ARG            NaN -0.700001
# ARM            NaN  0.400002
# AUS            NaN  0.000000
# AUT            NaN -0.600000
# AZE            NaN -0.100000

# %%
db.plot(kind = 'bar')
## db.hist(figsize =(25, 15))
## fig = plt.figure(figsize = (12, 9))
plt.show()
